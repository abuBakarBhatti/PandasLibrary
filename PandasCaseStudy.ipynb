# %% [markdown]
# ## Pandas Case Study
# We are going to import libraries

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#importing Titanic dataset into our new variable name as kashti

kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### Printing first five rows of the dataset

# %%
kashti.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Using Describe Function

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Conveting Data into CSV format

# %%
kashti.to_csv("kashti.csv")

# %% [markdown]
# ### Removing Data/columns from the data set

# %%
new_Kashti = kashti.drop(["embark_town", "alone"], axis=1)
new_Kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive
# ...

# %% [markdown]
# ### Mean of entire data frame

# %%
kashti.mean()
# Out:
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_900\3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %% [markdown]
# ### For Counting a particular column Values

# %%
# using value_count function
kashti.value_counts(["survived"])
# Out:
# survived
# 0           549
# 1           342
# dtype: int64

# %% [markdown]
# ### To see the comparision we use GroupBy function

# %%
kashti.groupby(["sex"]).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %% [markdown]
# #### We can also check the comparision between multiple columns

# %%
kashti.groupby(["sex", "class", "who"]).mean()
# Out:
#                      survived  pclass        age     sibsp     parch  \
# sex    class  who
# female First  child  0.666667     1.0  10.333333  0.666667  1.666667
#               man         NaN     NaN        NaN       NaN       NaN
#               woman  0.978022     1.0  35.500000  0.549451  0.417582
#        Second child  1.000000     2.0   6.600000  0.700000  1.300000
#               man         NaN     NaN        NaN       NaN       NaN
#               woman  0.909091     2.0  32.179688  0.454545  0.500000
#        Third  child  0.533333     3.0   7.100000  1.533333  1.100000
#               man         NaN     NaN        NaN       NaN       NaN
#               woman  0.491228     3.0  27.854167  0.728070  0.719298
# male   First  child  1.000000     1.0   5.306667  0.666667  2.000000
#               man    0.352941     1.0  42.382653  0.302521  0.235294
#               woman       NaN     NaN        NaN       NaN       NaN
# ...

# %% [markdown]
# ### We can also use comparision operators to apply filters

# %%
# We just want to see the chileren mean data in the sheet

kashti[kashti["age"] < 18].value_counts("age")

# above code shows filters only children and counts their ages
# Out:
# age
# 16.00    17
# 17.00    13
# 2.00     10
# 4.00     10
# 9.00      8
# 1.00      7
# 14.00     6
# 3.00      6
# 15.00     5
# 8.00      4
# 5.00      4
# 11.00     4
# 7.00      3
# 6.00      3
# 10.00     2
# 13.00     2
# 0.83      2
# 0.75      2
# 0.67      1
# 12.00     1
# 0.92      1
# 14.50     1
# 0.42      1
# dtype: int64

# %% [markdown]
# ### Using the above example and getting the mean

# %%
kashti[kashti["age"] < 18].mean()
# Out:
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_900\3288685250.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti[kashti["age"] < 18].mean()
# survived       0.539823
# pclass         2.584071
# age            9.041327
# sibsp          1.460177
# parch          1.053097
# fare          31.220798
# adult_male     0.159292
# alone          0.203540
# dtype: float64

# %%
kashti[kashti["age"] < 18].groupby(["sex", "class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# kashti["sex", "survived"].nunique()
(np.unique(kashti[['sex', 'class']]))
# Out:
# array(['First', 'Second', 'Third', 'female', 'male'], dtype=object)
